# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# ### Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Importing the Dataset

# %%
data=pd.read_csv("Salary_Data.csv")
X=data.iloc[:,:-1].values
y=data.iloc[:,-1].values

# %% [markdown]
# ### Splitting data into training and testing sets

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y, test_size=0.2, random_state=0)

# %% [markdown]
# ### Training the simple linear regression model on training dataset

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Predicting the test set result

# %%
y_pred=regressor.predict(X_test)

# %% [markdown]
# ### Visualizing the training set results

# %%
plt.scatter(X_train,y_train,c='red')
plt.plot(X_train,regressor.predict(X_train))
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.title('Predition of the training set')
# Out:
# Text(0.5, 1.0, 'Predition of the training set')

# %% [markdown]
# ### Visualizing the test set results

# %%
plt.scatter(X_test,y_test,color='red')
plt.plot(X_test,y_pred,color='green')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Prediction of test results')
# Out:
# Text(0.5, 1.0, 'Prediction of test results')

# %%
# plt.scatter(X_test,y_test,color='yellow')
# plt.plot(X_train,regressor.predict(X_train))
# plt.xlabel('Years of Experience')
# plt.ylabel('Salary')
# plt.title('Prediction of test results')

# The regression line for both the training set and the test set is same

# %% [markdown]
# ### Making a single prediction

# %%
regressor.predict([[100]])
# Out:
# array([958037.61182355])

# %%
print(regressor.coef_)
print(regressor.intercept_)
# Out:
# [9312.57512673]
# 26780.09915062818
